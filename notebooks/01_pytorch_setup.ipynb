# %% [markdown]
# # 01. Pytorch setup: Imports, version and basic check
#
# **Goal:** make a little job with a torch.
#
# **Source**: The Internet.
#
# Working with basic functions in Python and Torch.

# %%
import torch

# Checking the import and version
print(f"Tourch version: {torch.__version__}")

# Checking the CUDA (should be False, because CPU version)
print(f"Cuda availible: {torch.cuda.is_available()}")

# Simple operations: creating and adding tensors
a = torch.tensor([1, 2, 3])
b = torch.tensor([4, 5, 6])
print(f"a + b = {a} + {b} = {a + b}")
# Out:
# Tourch version: 2.9.0+cpu
# Cuda availible: False
# a + b = tensor([1, 2, 3]) + tensor([4, 5, 6]) = tensor([5, 7, 9])
